# %%
import pandas as pd

# %%
df = pd.read_csv('Datasets/EdX.csv')

# %%
df.head(10)
# Out:
#                                                 Name  \
# 0                                How to Learn Online
# 1  Programming for Everybody (Getting Started wit...
# 2            CS50's Introduction to Computer Science
# 3                                 The Analytics Edge
# 4  Marketing Analytics: Marketing Measurement Str...
# 5                 Introduction to Project Management
# 6                      Leading High-Performing Teams
# 7               The Foundations of Happiness at Work
# 8  Managing Study, Stress and Mental Health at Un...
# 9                      Six Sigma: Define and Measure
#
#                               University Difficulty Level  \
# 0                                    edX         Beginner
# 1             The University of Michigan         Beginner
# 2                     Harvard University         Beginner
# 3  Massachusetts Institute of Technology     Intermediate
# 4     University of California, Berkeley         Beginner
# 5                 University of Adelaide         Beginner
# 6           The University of Queensland     Intermediate
# 7     University of California, Berkeley         Beginner
# 8                      Curtin University         Beginner
# 9         Technische Universität München         Beginner
#
#                                                 Link  \
# 0     https://www.edx.org/course/how-to-learn-online
# 1  https://www.edx.org/course/programming-for-eve...
# 2  https://www.edx.org/course/cs50s-introduction-...
# 3      https://www.edx.org/course/the-analytics-edge
# 4  https://www.edx.org/course/marketing-analytics...
# 5  https://www.edx.org/course/introduction-to-pro...
# 6  https://www.edx.org/course/leading-high-perfor...
# 7  https://www.edx.org/course/the-foundations-of-...
# 8  https://www.edx.org/course/managing-study-stre...
# 9  https://www.edx.org/course/six-sigma-define-an...
#
#                                                About  \
# 0  Learn essential strategies for successful onli...
# 1  This course is a "no prerequisite" introductio...
# 2  An introduction to the intellectual enterprise...
# 3  Through inspiring examples and stories, discov...
# 4     This course is part of a MicroMasters® Program
# 5  Learn the principles of project management and...
# 6  Learn how to motivate, engage and empower peop...
# 7  Learn why happiness at work matters and how to...
# 8  Develop a clearer understanding of what mental...
# 9  An introduction to the Six Sigma methodology a...
#
#                                   Course Description
# 0  Designed for those who are new to elearning, t...
# 1  This course aims to teach everyone the basics ...
# 2  This is CS50x , Harvard University's introduct...
# 3  In the last decade, the amount of data availab...
# 4  Begin your journey in a new career in marketin...
# 5  Project management is an essential skill-set f...
# 6  This course will blend business theory and rea...
# 7  This course explains what happiness at work lo...
# 8  This short course is a German-Australian colla...
# 9  Understand the background and meaning of Six S...

# %%
df.tail()
# Out:
#                                                   Name  \
# 715         Global China: From the Mongols to the Ming
# 716  Leaders in Citizen Security and Justice Manage...
# 717  Computational Neuroscience: Neuronal Dynamics ...
# 718  Cities and the Challenge of Sustainable Develo...
# 719                      MathTrackX: Special Functions
#
#                                    University Difficulty Level  \
# 715                        Harvard University         Beginner
# 716           Inter-American Development Bank     Intermediate
# 717  École polytechnique fédérale de Lausanne         Advanced
# 718                               SDG Academy         Beginner
# 719                    University of Adelaide         Beginner
#
#                                                   Link  \
# 715  https://www.edx.org/course/global-china-from-t...
# 716  https://www.edx.org/course/leaders-in-citizen-...
# 717  https://www.edx.org/course/computational-neuro...
# 718  https://www.edx.org/course/cities-and-the-chal...
# 719  https://www.edx.org/course/mathtrackx-special-...
#
#                                                  About  \
# 715  Explore the impact of the conquest dynasties a...
# 716  Learn about the latest in prevention, police a...
# 717  This course explains the mathematical and comp...
# 718  What is a sustainable city? Learn the basics h...
# 719  Understand trigonometric, exponential and loga...
#
#                                     Course Description
# 715  In the 13th century, by force of arms, the Mon...
# 716  The high rates of crime and violence are two o...
# 717  What happens in your brain when you make a dec...
# 718  According to the United Nations, urbanization ...
# 719  This course is part two of the MathTrackX XSer...

# %%
df.shape
# Out:
# (720, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                720 non-null    object
#  1   University          720 non-null    object
#  2   Difficulty Level    720 non-null    object
#  3   Link                720 non-null    object
#  4   About               720 non-null    object
#  5   Course Description  720 non-null    object
# dtypes: object(6)
# memory usage: 33.9+ KB

# %%
df.describe()
# Out:
#                              Name          University Difficulty Level  \
# count                         720                 720              720
# unique                        717                 102                3
# top     Introduction to Marketing  Harvard University         Beginner
# freq                            2                  91              437
#
#                                                      Link  \
# count                                                 720
# unique                                                719
# top     https://www.edx.org/course/introduction-to-pro...
# freq                                                    2
#
#                                                  About  \
# count                                              720
# unique                                             698
# top     This course is part of a MicroMasters® Program
# freq                                                15
#
#                                        Course Description
# count                                                 720
# unique                                                717
# top     About the Database Series of Courses"Databases...
# freq                                                    3

# %%
df.columns
# Out:
# Index(['Name', 'University', 'Difficulty Level', 'Link', 'About',
#        'Course Description'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.isnull().sum()
# Out:
# Name                  0
# University            0
# Difficulty Level      0
# Link                  0
# About                 0
# Course Description    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                720 non-null    object
#  1   University          720 non-null    object
#  2   Difficulty Level    720 non-null    object
#  3   Link                720 non-null    object
#  4   About               720 non-null    object
#  5   Course Description  720 non-null    object
# dtypes: object(6)
# memory usage: 33.9+ KB

# %%
df.nunique()
# Out:
# Name                  717
# University            102
# Difficulty Level        3
# Link                  719
# About                 698
# Course Description    717
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df['University'].unique()
# Out:
# array(['edX', 'The University of Michigan', 'Harvard University',
#        'Massachusetts Institute of Technology',
#        'University of California, Berkeley', 'University of Adelaide',
#        'The University of Queensland', 'Curtin University',
#        'Technische Universität München',
#        'National Research Nuclear University', 'SDG Academy',
#        'University of Hong Kong', 'IBM',
#        'Wageningen University & Research', 'Boston University',
#        'Educational Testing Service',
#        'Universitat Politècnica de Valencia', 'The Linux Foundation',
#        'Indian Institute of Management Bangalore',
#        'The Georgia Institute of Technology', 'New York University',
#        'The World Wide Web Consortium (W3C)', 'Columbia University',
#        'Stanford University', 'Cornell University', 'Davidson College',
#        'Berklee College of Music', 'The Hong Kong Polytechnic University',
#        'University of Washington', 'Dartmouth_IMTx-Dartmouth College-IMT',
#        'University of Pennsylvania', 'United Arab Emirates University',
#        'The University of California, San Diego', 'MandarinX',
#        'Tsinghua University', 'The International Monetary Fund',
#        'University of British Columbia', 'IITBombay',
#        'Delft University of Technology',
#        'The Hong Kong University of Science and Technology',
#        'The University of Maryland, College Park-University System of Maryland',
#        'IsraelX-Tel Aviv University', 'University of Oxford',
#        'Doane University', 'University of Toronto',
#        'University System of Maryland-The University of Maryland, College Park',
#        'Rochester Institute of Technology',
#        'Imperial College Business School-Imperial College London',
#        'Catalyst', 'Universidad Carlos III de Madrid',
#        'Universidad Galileo', 'Université catholique de Louvain',
#        'Kyoto University', 'The National University of Singapore',
#        'Inter-American Development Bank', 'SchoolYourself',
#        'Universidades Anáhuac',
#        'The Wharton School of the University of Pennsylvania',
#        'The University of Texas at Austin', 'Tecnológico de Monterrey',
#        'Arizona State University', 'Rolls-Royce', 'Amnesty International',
#        'Wits University', 'Waseda University',
#        'The Smithsonian Institution',
#        'École polytechnique fédérale de Lausanne',
#        'Georgetown University', 'Babson College',
#        'The University of Tokyo', 'Australian National University',
#        'KU Leuven University', 'World Bank Group', 'Dartmouth College',
#        'NYIF', 'Chalmers University of Technology',
#        'Imperial College London',
#        'Salisbury University-University System of Maryland',
#        'Delft University of Technology-Wageningen University & Research-Delft University & Wageningen University',
#        'The University of Iceland', 'Western Governors University',
#        'University System of Maryland-University of Maryland Global Campus',
#        'Rice University', 'The University of Edinburgh',
#        'Université de Montréal', 'University of Texas at Arlington',
#        'ETH Zurich', 'Amazon Web Services',
#        'Università degli Studi di Napoli Federico II',
#        'Queen’s University',
#        'DelftXRWTHx-Delft University of Technology-RWTH Aachen University',
#        'The University of Texas of the Permian Basin',
#        'Tokyo Institute of Technology', 'IMT', 'Davidson Next',
#        'The University of Michigan-Microsoft Education',
#        'Ural Federal University', 'Arm Education',
#        'University of Baltimore-University System of Maryland',
#        'The Islamic Research and Training Institute',
#        'RWTH Aachen University',
#        'University of Maryland Global Campus-University System of Maryland'],
#       dtype=object)

# %%
df['University'].value_counts()
# Out:
# Harvard University                                                        91
# Massachusetts Institute of Technology                                     41
# Delft University of Technology                                            28
# The University of Queensland                                              25
# IBM                                                                       21
#                                                                           ..
# University of Oxford                                                       1
# University of Toronto                                                      1
# University System of Maryland-The University of Maryland, College Park     1
# Universidades Anáhuac                                                      1
# University of Maryland Global Campus-University System of Maryland         1
# Name: University, Length: 102, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(df['University'], data = df, palette = 'hls')
plt.xticks(rotation = 90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24296/3154015014.py in <module>
#       1 plt.figure(figsize=(15,6))
# ----> 2 sns.countplot(df['University'], data = df, palette = 'hls')
#       3 plt.xticks(rotation = 90)
#       4 plt.show()
#
# TypeError: countplot() got multiple values for argument 'data'

# %%
df['Difficulty Level'].unique()
# Out:
# array(['Beginner', 'Intermediate', 'Advanced'], dtype=object)

# %%
df['Difficulty Level'].value_counts()
# Out:
# Beginner        437
# Intermediate    205
# Advanced         78
# Name: Difficulty Level, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(df['Difficulty Level'], data = df, palette = 'hls')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24296/1770334159.py in <module>
#       1 plt.figure(figsize=(15,6))
# ----> 2 sns.countplot(df['Difficulty Level'], data = df, palette = 'hls')
#       3 plt.show()
#
# TypeError: countplot() got multiple values for argument 'data'

# %%
plt.figure(figsize=(30,20)) 
plt.pie(df['Difficulty Level'].value_counts(), labels=df['Difficulty Level'].value_counts().index, autopct='%1.1f%%', textprops={ 'fontsize': 25,
                                           'color': 'black',
                                           'weight': 'bold',
                                           'family': 'serif' }) 
hfont = {'fontname':'serif', 'weight': 'bold'}
plt.title('Difficulty Level', size=20, **hfont) 
plt.show()

# %%
df = df.drop(['Link'],axis=1)

# %%
import re
import string

# %%
def clean_text(text):
    '''Make text lowercase, remove text in square brackets,remove links,remove punctuation
    and remove words containing numbers.'''
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

# %%
df_new = df.copy()

# %%
df_new['About'] = df_new['About'].apply(clean_text)
df_new['Course Description'] = df_new['Course Description'].apply(clean_text)

# %%
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
stop_words = stopwords.words('english')
more_stopwords = ['u', 'im', 'c']
stop_words = stop_words + more_stopwords

def remove_stopwords(text):
    text = ' '.join(word for word in text.split(' ') if word not in stop_words)
    return text
    
df_new['About'] = df_new['About'].apply(remove_stopwords)
df_new['Course Description'] = df_new['Course Description'].apply(remove_stopwords)
# Out:
#                                                 Name  \
# 0                                How to Learn Online
# 1  Programming for Everybody (Getting Started wit...
# 2            CS50's Introduction to Computer Science
# 3                                 The Analytics Edge
# 4  Marketing Analytics: Marketing Measurement Str...
#
#                               University Difficulty Level  \
# 0                                    edX         Beginner
# 1             The University of Michigan         Beginner
# 2                     Harvard University         Beginner
# 3  Massachusetts Institute of Technology     Intermediate
# 4     University of California, Berkeley         Beginner
#
#                                                About  \
# 0  Learn essential strategies for successful onli...
# 1  This course is a "no prerequisite" introductio...
# 2  An introduction to the intellectual enterprise...
# 3  Through inspiring examples and stories, discov...
# 4     This course is part of a MicroMasters® Program
#
#                                   Course Description
# 0  Designed for those who are new to elearning, t...
# 1  This course aims to teach everyone the basics ...
# 2  This is CS50x , Harvard University's introduct...
# 3  In the last decade, the amount of data availab...
# 4  Begin your journey in a new career in marketin...

# %%
df_new.head()
# Out:
#                                                 Name  \
# 0                                How to Learn Online
# 1  Programming for Everybody (Getting Started wit...
# 2            CS50's Introduction to Computer Science
# 3                                 The Analytics Edge
# 4  Marketing Analytics: Marketing Measurement Str...
#
#                               University Difficulty Level  \
# 0                                    edX         Beginner
# 1             The University of Michigan         Beginner
# 2                     Harvard University         Beginner
# 3  Massachusetts Institute of Technology     Intermediate
# 4     University of California, Berkeley         Beginner
#
#                                                About  \
# 0  learn essential strategies successful online l...
# 1  course prerequisite introduction python progra...
# 2  introduction intellectual enterprises computer...
# 3  inspiring examples stories discover power data...
# 4                  course part micromasters® program
#
#                                   Course Description
# 0  designed new elearning course prepare strategi...
# 1  course aims teach everyone basics programming ...
# 2    harvard universitys introduction intellectua...
# 3  last decade amount data available organization...
# 4  begin journey new career marketing analytics l...

# %%
stemmer = nltk.SnowballStemmer("english")

def stemm_text(text):
    text = ' '.join(stemmer.stem(word) for word in text.split(' '))
    return text

# %%
df_new['About'] = df_new['About'].apply(stemm_text)
df_new['Course Description'] = df_new['Course Description']
df_new.head()
# Out:
#                                                 Name  \
# 0                                How to Learn Online
# 1  Programming for Everybody (Getting Started wit...
# 2            CS50's Introduction to Computer Science
# 3                                 The Analytics Edge
# 4  Marketing Analytics: Marketing Measurement Str...
#
#                               University Difficulty Level  \
# 0                                    edX         Beginner
# 1             The University of Michigan         Beginner
# 2                     Harvard University         Beginner
# 3  Massachusetts Institute of Technology     Intermediate
# 4     University of California, Berkeley         Beginner
#
#                                                About  \
# 0         learn essenti strategi success onlin learn
# 1  cours prerequisit introduct python program lea...
# 2  introduct intellectu enterpris comput scienc a...
# 3  inspir exampl stori discov power data use anal...
# 4                   cours part micromasters® program
#
#                                   Course Description
# 0  designed new elearning course prepare strategi...
# 1  course aims teach everyone basics programming ...
# 2    harvard universitys introduction intellectua...
# 3  last decade amount data available organization...
# 4  begin journey new career marketing analytics l...

# %%
def ngrams_func(i,j):
    count_vectoriser = CountVectorizer(ngram_range=(i,j))
    ngrams = count_vectoriser.fit_transform(df_new["Course Description"])
    count_values = ngrams.toarray().sum(axis=0)
    vocab=count_vectoriser.vocabulary_
    return count_values,vocab

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import word_tokenize

# %%
count_values,vocab=ngrams_func(3,3)
df_trigrams = pd.DataFrame(sorted([(count_values[i],k)
                                  for k,i in vocab.items()], reverse=True)).rename(columns={0:'Freq',1:'Trigrams'})
df_trigrams.head(7)
# Out:
#    Freq                          Trigrams
# 0    52          data analysis statistics
# 1    40                      you ll learn
# 2    40  professional certificate program
# 3    29             biology life sciences
# 4    24                     course you ll
# 5    22                   end course able
# 6    18        education teacher training

# %%
count_values,vocab= ngrams_func(2,2)
df_bigrams = pd.DataFrame(sorted([(count_values[i],k) for k,i in vocab.items()],reverse=True)).rename(columns={0:'Freq',1:'Bigrams'})
df_bigrams.head()
# Out:
#    Freq              Bigrams
# 0   157     computer science
# 1   136  business management
# 2   122               you ll
# 3   112          course part
# 4   101         course learn

# %%
freq_of_words = pd.Series(' '.join(df_new["Course Description"]).split()).value_counts()[:15]
freq_of_words
# Out:
# course           2058
# learn             730
# data              506
# business          405
# also              356
# science           333
# management        327
# learning          296
# skills            277
# understanding     246
# program           244
# use               239
# world             238
# design            237
# part              226
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(df_new['Difficulty Level'])

df_new['Difficulty Level'] = le.transform(df_new['Difficulty Level'])
df_new.head()
# Out:
#                                                 Name  \
# 0                                How to Learn Online
# 1  Programming for Everybody (Getting Started wit...
# 2            CS50's Introduction to Computer Science
# 3                                 The Analytics Edge
# 4  Marketing Analytics: Marketing Measurement Str...
#
#                               University  Difficulty Level  \
# 0                                    edX                 1
# 1             The University of Michigan                 1
# 2                     Harvard University                 1
# 3  Massachusetts Institute of Technology                 2
# 4     University of California, Berkeley                 1
#
#                                                About  \
# 0         learn essenti strategi success onlin learn
# 1  cours prerequisit introduct python program lea...
# 2  introduct intellectu enterpris comput scienc a...
# 3  inspir exampl stori discov power data use anal...
# 4                   cours part micromasters® program
#
#                                   Course Description
# 0  designed new elearning course prepare strategi...
# 1  course aims teach everyone basics programming ...
# 2    harvard universitys introduction intellectua...
# 3  last decade amount data available organization...
# 4  begin journey new career marketing analytics l...

# %%
import numpy as np

# %%
twitter_mask = np.array(Image.open('twitter_mask.png'))

wc = WordCloud(
    background_color='white', 
    max_words=200, 
    mask=twitter_mask,
)
wc.generate(' '.join(text for text in df.loc[df_new['Difficulty Level'] == 0, 'Course Description']))
plt.figure(figsize=(18,10))
plt.title('Top words for Course Description - Beginner', 
          fontdict={'size': 22,  'verticalalignment': 'bottom'})
plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
twitter_mask = np.array(Image.open('twitter_mask.png'))

wc = WordCloud(
    background_color='white', 
    max_words=200, 
    mask=twitter_mask,
)
wc.generate(' '.join(text for text in df.loc[df_new['Difficulty Level'] == 1, 'Course Description']))
plt.figure(figsize=(18,10))
plt.title('Top words for Course Description - Intermediate', 
          fontdict={'size': 22,  'verticalalignment': 'bottom'})
plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
twitter_mask = np.array(Image.open('twitter_mask.png'))

wc = WordCloud(
    background_color='white', 
    max_words=200, 
    mask=twitter_mask,
)
wc.generate(' '.join(text for text in df.loc[df_new['Difficulty Level'] == 2, 'Course Description']))
plt.figure(figsize=(18,10))
plt.title('Top words for Course Description - Advanced', 
          fontdict={'size': 22,  'verticalalignment': 'bottom'})
plt.imshow(wc)
plt.axis("off")
plt.show()
